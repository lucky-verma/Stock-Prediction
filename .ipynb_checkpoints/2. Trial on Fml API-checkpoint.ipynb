# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import yfinance as yf
import io, base64, os, json, re 
import pandas as pd
import numpy as np
import datetime
import json
import requests
from urllib.request import urlopen
from random import randint

# %%
df = pd.read_csv('AAPL_1hr.csv')
df.tail(3)
# Out:
#      Unnamed: 0                 date      open      low      high     close  \
# 197         197  2020-11-13 15:00:00  118.6950  118.205  118.8899  118.8850
# 198         198  2020-11-13 14:00:00  118.9466  118.500  119.2250  118.5700
# 199         199  2020-11-13 13:00:00  118.9493  118.820  118.9493  118.9466
#
#        volume
# 197  58545638
# 198  51025438
# 199  43274698

# %%
df.drop ('Unnamed: 0', axis=1, inplace=True)

# %%
df.tail(1)
# Out:
#                     date      open     low      high     close    volume
# 199  2020-11-13 13:00:00  118.9493  118.82  118.9493  118.9466  43274698

# %%
df['date'] = df['date'].str.slice(0, -9, 1)

# %%
df.head(3)
# Out:
#          date      open     low      high   close    volume
# 0  2020-12-24  131.9700  131.97  131.9700  131.97  54213606
# 1  2020-12-24  131.9700  131.97  131.9700  131.97  54213606
# 2  2020-12-24  132.0059  131.97  132.0059  131.97  54213606

# %% [markdown]
# 	Open	High	Low	Close	Adj Close	Volume	Date

# %%
df['Date'] = df['date']
df['Open'] = df['open']
df['High'] = df['high']
df['Low'] = df['low']
df['Close'] = df['close']
df['Adj Close'] = df['close']
df['Volume'] = df['volume']
df.drop ('date', axis=1, inplace=True)
df.drop ('open', axis=1, inplace=True)
df.drop ('high', axis=1, inplace=True)
df.drop ('low', axis=1, inplace=True)
df.drop ('close', axis=1, inplace=True)
df.drop ('volume', axis=1, inplace=True)
df.head(2)
# Out:
#          Date    Open    High     Low   Close  Adj Close    Volume
# 0  2020-12-24  131.97  131.97  131.97  131.97     131.97  54213606
# 1  2020-12-24  131.97  131.97  131.97  131.97     131.97  54213606

# %%
csv_data = df.to_csv('AAPL_1hr_EDITED.csv', index = True)

# %% [markdown]
# ## Perform 2. operation here

# %%
new_set = []
for row_set in range(0, 1000000):
    if row_set%2000==0: print(row_set)
    row_quant = randint(10, 30)
    row_start = randint(0, len(df)-row_quant)
    market_subset = df.iloc[row_start:row_start+row_quant]

    Close_Date = max(market_subset['Date'])
    if row_set%2000==0: print(Close_Date)
    
    # Close_Gap = (market_subset['Close'] - market_subset['Close'].shift(1)) / market_subset['Close'].shift(1)
    Close_Gap = market_subset['Close'].pct_change()
    High_Gap = market_subset['High'].pct_change()
    Low_Gap = market_subset['Low'].pct_change() 
    Volume_Gap = market_subset['Volume'].pct_change() 
    Daily_Change = (market_subset['Close'] - market_subset['Open']) / market_subset['Open']
    Outcome_Next_Day_Direction = (market_subset['Volume'].shift(-1) - market_subset['Volume'])
    
    new_set.append(pd.DataFrame({'Sequence_ID':[row_set]*len(market_subset),
                            'Close_Date':[Close_Date]*len(market_subset),
                           'Close_Gap':Close_Gap,
                           'High_Gap':High_Gap,
                           'Low_Gap':Low_Gap,
                           'Volume_Gap':Volume_Gap,
# 834000
# 2020-12-07
# 836000
# 2020-11-25
# 838000
# 2020-12-09
# 840000
# 2020-12-10
# 842000
# 2020-11-19
# 844000
# 2020-11-24
# 846000
# 2020-11-19
# 848000
# 2020-12-03
# 850000
# 2020-12-16
# 852000
# 2020-12-03
# 854000
# 2020-11-27
# 856000
# 2020-12-02
# 858000
# 2020-12-22
# 860000
# 2020-12-10
# 862000
# 2020-12-17
# 864000
# 2020-11-16
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-d4580b8462bf> in <module>()
#      10
#      11     # Close_Gap = (market_subset['Close'] - market_subset['Close'].shift(1)) / market_subset['Close'].shift(1)
# ---> 12     Close_Gap = market_subset['Close'].pct_change()
#      13     High_Gap = market_subset['High'].pct_change()
#      14     Low_Gap = market_subset['Low'].pct_change()
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10235             data = self
#   10236         else:
# > 10237             _data = self.fillna(method=fill_method, axis=axis, limit=limit)
#   10238             assert _data is not None  # needed for mypy
#   10239             data = _data
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\series.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4533             inplace=inplace,
#    4534             limit=limit,
# -> 4535             downcast=downcast,
#    4536         )
#    4537
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6036                 inplace=inplace,
#    6037                 coerce=True,
# -> 6038                 downcast=downcast,
#    6039             )
#    6040         else:
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     559
#     560     def interpolate(self, **kwargs) -> "BlockManager":
# --> 561         return self.apply("interpolate", **kwargs)
#     562
#     563     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\internals\blocks.py in interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1121                 fill_value=fill_value,
#    1122                 coerce=coerce,
# -> 1123                 downcast=downcast,
#    1124             )
#    1125         # validate the interp method
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\internals\blocks.py in _interpolate_with_fill(self, method, axis, inplace, limit, fill_value, coerce, downcast)
#    1174             limit=limit,
#    1175             fill_value=fill_value,
# -> 1176             dtype=self.dtype,
#    1177         )
#    1178
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\missing.py in interpolate_2d(values, method, axis, limit, fill_value, dtype)
#     568     method = clean_fill_method(method)
#     569     if method == "pad":
# --> 570         values = transf(pad_2d(transf(values), limit=limit, mask=mask, dtype=dtype))
#     571     else:
#     572         values = transf(
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\missing.py in pad_2d(values, limit, mask, dtype)
#     637
#     638     if np.all(values.shape):
# --> 639         algos.pad_2d_inplace(values, mask, limit=limit)
#     640     else:
#     641         # for test coverage
#
# pandas\_libs\algos.pyx in pandas._libs.algos.pad_2d_inplace()
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\_libs\algos.cp37-win_amd64.pyd in View.MemoryView.memoryview_cwrapper()
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\_libs\algos.cp37-win_amd64.pyd in View.MemoryView.memoryview.__cinit__()
#
# MemoryError:

# %%
len(market_subset)
# Out:
# 16

# %%
new_set_df = pd.concat(new_set)
print(new_set_df.shape)
new_set_df = new_set_df.dropna(how='any') 
print(new_set_df.shape)
# Out:
# (17305334, 8)
# (15576084, 8)

# %%
new_set_df.tail(5)
# Out:
#      Sequence_ID  Close_Date  Close_Gap  High_Gap   Low_Gap  Volume_Gap  \
# 142       864624  2020-11-30  -0.000732  0.001684  0.001279   -0.106142
# 143       864624  2020-11-30   0.001681 -0.000005 -0.001535   -0.102740
# 144       864624  2020-11-30  -0.001592 -0.001902  0.001728   -0.139572
# 145       864624  2020-11-30   0.004094  0.003499  0.001763   -0.256339
# 146       864624  2020-11-30  -0.001459  0.000558 -0.007702   -0.442267
#
#      Daily_Change  Outcome_Next_Day_Direction
# 142     -0.002108                  -5277039.0
# 143      0.001595                  -6432301.0
# 144      0.000122                 -10164782.0
# 145      0.002927                 -13041984.0
# 146      0.005185                  87103686.0

# %%
new_set_df.head()
# Out:
#      Sequence_ID  Close_Date  Close_Gap  High_Gap   Low_Gap  Volume_Gap  \
# 119            0  2020-12-02   0.005410  0.001589  0.009589    5.541484
# 120            0  2020-12-02   0.000448  0.002319  0.004176   -0.149333
# 121            0  2020-12-02   0.000515  0.000609 -0.000162   -0.099965
# 122            0  2020-12-02  -0.001085 -0.002473  0.000122   -0.099960
# 123            0  2020-12-02   0.003792  0.001957  0.001962   -0.156633
#
#      Daily_Change  Outcome_Next_Day_Direction
# 119      0.001184                 -17159914.0
# 120     -0.000326                  -9771591.0
# 121      0.001086                  -8794339.0
# 122     -0.002278                 -12402942.0
# 123      0.001790                 -17786559.0

# %%
new_set_df['Close_Gap_LMH'] = pd.qcut(new_set_df['Close_Gap'], 3, labels=["L", "M", "H"])

# High_Gap - not used in this example
new_set_df['High_Gap_LMH'] = pd.qcut(new_set_df['High_Gap'], 3, labels=["L", "M", "H"])

# Low_Gap - not used in this example
new_set_df['Low_Gap_LMH'] = pd.qcut(new_set_df['Low_Gap'], 3, labels=["L", "M", "H"])

# Volume_Gap
new_set_df['Volume_Gap_LMH'] = pd.qcut(new_set_df['Volume_Gap'], 3, labels=["L", "M", "H"])
 
# Daily_Change
new_set_df['Daily_Change_LMH'] = pd.qcut(new_set_df['Daily_Change'], 3, labels=["L", "M", "H"])

# new set
new_set_df = new_set_df[["Sequence_ID", 
                         "Close_Date", 
                         "Close_Gap_LMH", 
                         "Volume_Gap_LMH", 
                         "Daily_Change_LMH", 
                         "Outcome_Next_Day_Direction"]]

new_set_df['Event_Pattern'] = new_set_df['Close_Gap_LMH'].astype(str) + new_set_df['Volume_Gap_LMH'].astype(str) + new_set_df['Daily_Change_LMH'].astype(str)

# %%
new_set_df.tail()
# Out:
#      Sequence_ID  Close_Date Close_Gap_LMH Volume_Gap_LMH Daily_Change_LMH  \
# 142       864624  2020-11-30             M              H                L
# 143       864624  2020-11-30             M              H                H
# 144       864624  2020-11-30             L              M                M
# 145       864624  2020-11-30             H              L                H
# 146       864624  2020-11-30             L              L                H
#
#      Outcome_Next_Day_Direction Event_Pattern
# 142                  -5277039.0           MHL
# 143                  -6432301.0           MHH
# 144                 -10164782.0           LMM
# 145                 -13041984.0           HLH
# 146                  87103686.0           LLH

# %%
new_set_df['Outcome_Next_Day_Direction'].describe()
# Out:
# count    1.557608e+07
# mean    -1.106790e+05
# std      2.944470e+07
# min     -3.226512e+07
# 25%     -1.281047e+07
# 50%     -9.291756e+06
# 75%     -6.504771e+06
# max      1.399280e+08
# Name: Outcome_Next_Day_Direction, dtype: float64

# %%
compressed_set = new_set_df.groupby(['Sequence_ID', 
                                     'Close_Date'])['Event_Pattern'].apply(
                                        lambda x: "{%s}" % ', '.join(x)).reset_index()

print(compressed_set.shape)
compressed_set.head()
# Out:
# (864625, 3)
#    Sequence_ID  Close_Date                                      Event_Pattern
# 0            0  2020-12-02  {HHM, MMM, MHM, MHL, HMH, LLH, MLH, LHL, HLH, ...
# 1            1  2020-12-24  {LHL, HML, HHM, MHM, LMM, MLL, HLH, LHM, MHL, ...
# 2            2  2020-11-23  {HHH, LMM, HLM, HLL, HHL, HLL, MHL, HHH, LMM, ...
# 3            3  2020-12-10  {HHH, LHL, HMM, MLH, LLM, LHM, LMM, MML, HLL, ...
# 4            4  2020-11-20  {HLM, LLL, HHM, MMH, LHH, LHL, HMH, LLM, MLL, ...

# %%
compressed_outcomes = new_set_df.groupby(['Sequence_ID', 'Close_Date'])['Outcome_Next_Day_Direction'].mean()
compressed_outcomes = compressed_outcomes.to_frame().reset_index()
print(compressed_outcomes.shape)
compressed_outcomes.describe()
# Out:
# (864625, 3)
#          Sequence_ID  Outcome_Next_Day_Direction
# count  864625.000000                8.646250e+05
# mean   432312.000000               -9.097539e+04
# std    249595.882587                2.731467e+06
# min         0.000000               -1.089279e+07
# 25%    216156.000000               -1.525839e+06
# 50%    432312.000000               -8.100200e+04
# 75%    648468.000000                1.245178e+06
# max    864624.000000                1.793632e+07

# %%
compressed_set = pd.merge(compressed_set, compressed_outcomes, on= ['Sequence_ID', 'Close_Date'], how='inner')
print(compressed_set.shape)
compressed_set.head()
# Out:
# (864625, 4)
#    Sequence_ID  Close_Date                                      Event_Pattern  \
# 0            0  2020-12-02  {HHM, MMM, MHM, MHL, HMH, LLH, MLH, LHL, HLH, ...
# 1            1  2020-12-24  {LHL, HML, HHM, MHM, LMM, MLL, HLH, LHM, MHL, ...
# 2            2  2020-11-23  {HHH, LMM, HLM, HLL, HHL, HLL, MHL, HHH, LMM, ...
# 3            3  2020-12-10  {HHH, LHL, HMM, MLH, LLM, LHM, LMM, MML, HLL, ...
# 4            4  2020-11-20  {HLM, LLL, HHM, MMH, LHH, LHL, HMH, LLM, MLL, ...
#
#    Outcome_Next_Day_Direction
# 0               -5.163521e+06
# 1                1.562613e+06
# 2               -2.249160e+05
# 3               -1.926128e+05
# 4                1.389467e+06

# %%
compressed_set['Event_Pattern'] = [''.join(e.split()).replace('{','')
                                   .replace('}','') for e in compressed_set['Event_Pattern'].values]
compressed_set.head()
# Out:
#    Sequence_ID  Close_Date                                      Event_Pattern  \
# 0            0  2020-12-02  HHM,MMM,MHM,MHL,HMH,LLH,MLH,LHL,HLH,LLH,LMH,MM...
# 1            1  2020-12-24  LHL,HML,HHM,MHM,LMM,MLL,HLH,LHM,MHL,HHH,LHH,LM...
# 2            2  2020-11-23  HHH,LMM,HLM,HLL,HHL,HLL,MHL,HHH,LMM,HLM,LLL,HH...
# 3            3  2020-12-10  HHH,LHL,HMM,MLH,LLM,LHM,LMM,MML,HLL,HLL,HLH,HL...
# 4            4  2020-11-20  HLM,LLL,HHM,MMH,LHH,LHL,HMH,LLM,MLL,MHL,HLH,MH...
#
#    Outcome_Next_Day_Direction
# 0               -5.163521e+06
# 1                1.562613e+06
# 2               -2.249160e+05
# 3               -1.926128e+05
# 4                1.389467e+06

# %%
compressed_set_validation = compressed_set[compressed_set['Close_Date'] >= datetime.datetime.now() 
                                           - datetime.timedelta(days=90)] # Sys.Date()-90 

compressed_set_validation.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-fcef5ef11201> in <module>()
#       1 compressed_set_validation = compressed_set[compressed_set['Close_Date'] >= datetime.datetime.now()
# ----> 2                                            - datetime.timedelta(days=90)] # Sys.Date()-90
#       3
#       4 compressed_set_validation.shape
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     242
#     243     elif is_object_dtype(lvalues.dtype):
# --> 244         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     245
#     246     else:
#
# C:\Users\lucki\WORK\Anaconda3\envs\z-m\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      55     else:
# ---> 56         result = libops.scalar_compare(x.ravel(), y, op)
#      57     return result.reshape(x.shape)
#      58
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'datetime.datetime'

# %%
compressed_set = compressed_set[compressed_set['Close_Date'] < datetime.datetime.now() 
                                           - datetime.timedelta(days=90)]  
compressed_set.shape

# %%
list(compressed_set)

# %%
compressed_set = compressed_set[['Sequence_ID', 
                                 'Event_Pattern','Outcome_Next_Day_Direction']]
compressed_set_validation = compressed_set_validation[['Sequence_ID', 
                                                       'Event_Pattern','Outcome_Next_Day_Direction']]

# %%
compressed_set['Outcome_Next_Day_Direction'].describe()

# %%
print(len(compressed_set['Outcome_Next_Day_Direction']))
len(compressed_set[abs(compressed_set['Outcome_Next_Day_Direction']) > 10000000])

# %%
print('all moves:', len(compressed_set))
compressed_set = compressed_set[abs(compressed_set['Outcome_Next_Day_Direction']) > 10000000]
compressed_set['Outcome_Next_Day_Direction'] = np.where((compressed_set['Outcome_Next_Day_Direction'] 
                                                         > 0), 1, 0)
compressed_set_validation['Outcome_Next_Day_Direction'] = np.where(
                                (compressed_set_validation['Outcome_Next_Day_Direction'] > 0), 1, 0)
print('big moves only:', len(compressed_set))

# %%
compressed_set.head()

# %%
compressed_set_pos = compressed_set[compressed_set['Outcome_Next_Day_Direction']==1][
                                                    ['Sequence_ID', 'Event_Pattern']]
print(compressed_set_pos.shape)
compressed_set_neg = compressed_set[compressed_set['Outcome_Next_Day_Direction']==0][
                                                    ['Sequence_ID', 'Event_Pattern']]
print(compressed_set_neg.shape)

# %%
flat_list = [item.split(',') for item in compressed_set['Event_Pattern'].values ]
unique_patterns = ','.join(str(r) for v in flat_list for r in v)
unique_patterns = list(set(unique_patterns.split(',')))
len(unique_patterns)

# %%
compressed_set['Outcome_Next_Day_Direction'].head()

# %%
def build_transition_grid(compressed_grid, unique_patterns):
    # build the markov transition grid

    patterns = []
    counts = []
    for from_event in unique_patterns:

        # how many times 
        for to_event in unique_patterns:
            pattern = from_event + ',' + to_event # MMM,MlM

            ids_matches = compressed_grid[compressed_grid['Event_Pattern'].str.contains(pattern)]
            found = 0
            if len(ids_matches) > 0:
                Event_Pattern = '---'.join(ids_matches['Event_Pattern'].values)
                found = Event_Pattern.count(pattern)
            patterns.append(pattern)
            counts.append(found)

    # create to/from grid
    grid_Df = pd.DataFrame({'pairs':patterns, 'counts': counts})

    grid_Df['x'], grid_Df['y'] = grid_Df['pairs'].str.split(',', 1).str
    grid_Df.head()

    grid_Df = grid_Df.pivot(index='x', columns='y', values='counts')

    grid_Df.columns= [col for col in grid_Df.columns]
    del grid_Df.index.name

    # replace all NaN with zeros
    grid_Df.fillna(0, inplace=True)
    grid_Df.head()

    #grid_Df.rowSums(transition_dataframe) 
    grid_Df = grid_Df / grid_Df.sum(1)
    return (grid_Df)

# %%
grid_pos = build_transition_grid(compressed_set_pos, unique_patterns) 
grid_neg = build_transition_grid(compressed_set_neg, unique_patterns)

# %%
grid_neg.head()

# %%
grid_pos.head()

# %%
def safe_log(x,y):
   try:
      lg = np.log(x/y)
   except:
      lg = 0
   return lg

# predict on out of sample data
actual = []
predicted = []
for seq_id in compressed_set_validation['Sequence_ID'].values:
    patterns = compressed_set_validation[compressed_set_validation['Sequence_ID'] == seq_id]['Event_Pattern'].values[0].split(',')
    pos = []
    neg = []
    log_odds = []
    
    for id in range(0, len(patterns)-1):
        # get log odds
        # logOdds = log(tp(i,j) / tn(i,j)
        if (patterns[id] in list(grid_pos) and patterns[id+1] in list(grid_pos) and patterns[id] in list(grid_neg) and patterns[id+1] in list(grid_neg)):
                
            numerator = grid_pos[patterns[id]][patterns[id+1]]
            denominator = grid_neg[patterns[id]][patterns[id+1]]
            if (numerator == 0 and denominator == 0):
                log_value =0
            elif (denominator == 0):
                log_value = np.log(numerator / 0.00001)
            elif (numerator == 0):
                log_value = np.log(0.00001 / denominator)
            else:
                log_value = np.log(numerator/denominator)
        else:
            log_value = 0
        
        log_odds.append(log_value)
        
        pos.append(numerator)
        neg.append(denominator)
      
    print('outcome:', compressed_set_validation[compressed_set_validation['Sequence_ID']==seq_id]['Outcome_Next_Day_Direction'].values[0])
    print(sum(pos)/sum(neg))
    print(sum(log_odds))

    actual.append(compressed_set_validation[compressed_set_validation['Sequence_ID']==seq_id]['Outcome_Next_Day_Direction'].values[0])
    predicted.append(sum(log_odds))

from sklearn.metrics import confusion_matrix

confusion_matrix(actual, [1 if p > 0 else 0 for p in predicted])

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(actual, [1 if p > 0 else 0 for p in predicted])
print('Accuracy:', round(score * 100,2), '%')

# %%
import seaborn as sns
cm = confusion_matrix(actual, [1 if p > 0 else 0 for p in predicted])
fig, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, ax = ax, fmt='g')

ax.set_title('Confusion Matrix') 
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')

ax.xaxis.set_ticklabels(['up day','down day'])
ax.yaxis.set_ticklabels(['up day','down day'])
ax.set_yticklabels(ax.get_yticklabels(), rotation = 0, fontsize = 8)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90, fontsize = 8)  
plt.show()
